# %%
# Extracting the S&P 500 stocks 
import yfinance as yf 
import pandas as pd
from itertools import combinations
from skopt import gp_minimize
import random
from scipy.stats import pearsonr
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import coint
import statsmodels.api as sm
from statsmodels.regression.linear_model import OLS
from matplotlib import pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

SEED = 8
random.seed(SEED)
np.random.seed(SEED)


# Run it if u get an error saying u do not have "skopt"
# !pip install scikit-optimize

# %%
def fetch_sp500_data(start_date="2023-01-01", end_date="2024-01-01"):
    """
    Fetches S&P 500 stocks from Wikipedia, then downloads daily price data using yfinance.
    Returns the dataframe containing the stock data.
    """
    import yfinance as yf
    import pandas as pd
    
    # Step 1: Get S&P 500 tickers
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    sp500_table = pd.read_html(url)[0]
    sp500_tickers = sp500_table["Symbol"].tolist()
    
    # Step 2: Fetch stock data
    sp500_data = yf.download(sp500_tickers, interval="1d", start=start_date, end=end_date, auto_adjust=False)
    
    print(sp500_data.head())
    return sp500_data

# %%
def prepare_close_prices_and_pairs(sp500_data, max_na_threshold=1):
    """
    Extracts the Close prices from the S&P 500 data, removes columns with excessive NaN values,
    and generates all possible stock pairs.

    Parameters:
        sp500_data (DataFrame): The full S&P 500 stock data.
        max_na_threshold (int): Maximum allowed NaN values per column. Columns with more NaNs are dropped.

    Returns:
        close_price (DataFrame): Cleaned DataFrame containing only the Close prices.
        stock_pairs (list): List of all possible stock pairs (combinations of tickers).
        tickers (list): List of tickers after cleaning.
    """
    # Extract Close prices
    close_price = sp500_data["Close"]
    
    # Identify columns with excessive NaN values
    list_of_na_columns = [col for col in close_price if close_price[col].isna().sum() > max_na_threshold]
    
    # Drop columns with excessive NaN values
    close_price = close_price.drop(columns=list_of_na_columns)
    
    # Generate all possible stock pairs
    stock_pairs = list(combinations(close_price.columns, 2))
    
    # Get the list of tickers
    tickers = close_price.columns.tolist()
    
    return close_price, stock_pairs, tickers

# close_price, stock_pairs, tickers = prepare_close_prices_and_pairs(sp500_data)

# %%
def calculate_indicators(close_price):
    """
    Calculates SMA-5, SMA-10, and 10-day rolling volatility for all stocks in the given Close price DataFrame.

    Parameters:
        close_price (DataFrame): DataFrame containing Close prices of stocks.

    Returns:
        combined_df (DataFrame): A MultiIndex DataFrame containing Close prices, SMA-5, SMA-10, and Volatility.
    """
    # Base DataFrame with MultiIndex for Close prices
    price_df = close_price.copy()
    price_df.columns = pd.MultiIndex.from_product([['Close'], price_df.columns])

    # Containers for multiple SMAs and volatility
    sma_5_cols = []
    sma_10_cols = []
    volatility_cols = []

    # Calculate daily returns
    returns = close_price.pct_change()

    # Calculate 10-day rolling volatility
    for ticker in close_price.columns:
        vol = returns[ticker].rolling(window=10).std()
        volatility_cols.append(vol.rename(ticker))

    # Combine volatility into MultiIndex DataFrame
    volatility_df = pd.concat(volatility_cols, axis=1)
    volatility_df.columns = pd.MultiIndex.from_product([['Volatility'], volatility_df.columns])

    # Calculate SMA-5 and SMA-10 for all stocks
    for ticker in close_price.columns:
        series = close_price[ticker]
        
        # SMA-5
        sma_5 = series.rolling(window=5).mean()
        sma_5_cols.append(sma_5.rename(ticker))
        
        # SMA-10
        sma_10 = series.rolling(window=10).mean()
        sma_10_cols.append(sma_10.rename(ticker))

    # Combine SMA-5 into MultiIndex DataFrame
    sma_5_df = pd.concat(sma_5_cols, axis=1)
    sma_5_df.columns = pd.MultiIndex.from_product([['SMA-5'], sma_5_df.columns])

    # Combine SMA-10 into MultiIndex DataFrame
    sma_10_df = pd.concat(sma_10_cols, axis=1)
    sma_10_df.columns = pd.MultiIndex.from_product([['SMA-10'], sma_10_df.columns])

    # Merge all indicators into a single DataFrame
    combined_df = pd.concat([price_df, sma_5_df, sma_10_df, volatility_df], axis=1)

    return combined_df

# combined_df = calculate_indicators(close_price)

# %%
def find_cointegrated_pairs(combined_df, tickers, cointegration_threshold=0.05, n_calls=50, random_state=42):
    """
    Finds cointegrated pairs of stocks using Bayesian Optimization.

    Parameters:
        combined_df (DataFrame): MultiIndex DataFrame containing Close prices, SMA-5, SMA-10, and Volatility.
        tickers (list): List of stock tickers.
        cointegration_threshold (float): Threshold for cointegration p-value to consider a pair significant.
        n_calls (int): Number of calls for Bayesian Optimization.
        random_state (int): Random state for reproducibility.

    Returns:
        found_pairs (list): List of tuples containing cointegrated pairs and their p-values.
    """
    remaining_tickers = tickers.copy()
    found_pairs = []
    evaluated_pairs = set()

    def cointegration_test(params):
        idx1, idx2 = sorted([int(params[0]), int(params[1])])
        pair = (idx1, idx2)

        if idx1 == idx2 or pair in evaluated_pairs:
            return 1.0

        evaluated_pairs.add(pair)
        stock1, stock2 = remaining_tickers[idx1], remaining_tickers[idx2]

        s1_close = combined_df[('Close', stock1)].dropna()
        s2_close = combined_df[('Close', stock2)].dropna()
        s1_sma5 = combined_df[('SMA-5', stock1)].dropna()
        s2_sma5 = combined_df[('SMA-5', stock2)].dropna()
        s1_sma10 = combined_df[('SMA-10', stock1)].dropna()
        s2_sma10 = combined_df[('SMA-10', stock2)].dropna()
        s1_vol = combined_df[('Volatility', stock1)].dropna()
        s2_vol = combined_df[('Volatility', stock2)].dropna()

        aligned = pd.concat([s1_close, s2_close, s1_sma5, s2_sma5, s1_sma10, s2_sma10,
                             s1_vol, s2_vol], axis=1, join='inner').dropna()

        if len(aligned) < 30:
            return 1.0

        s1_close = aligned.iloc[:, 0]
        s2_close = aligned.iloc[:, 1]
        s1_sma5 = aligned.iloc[:, 2]
        s2_sma5 = aligned.iloc[:, 3]
        s1_sma10 = aligned.iloc[:, 4]
        s2_sma10 = aligned.iloc[:, 5]
        s1_vol = aligned.iloc[:, 6]
        s2_vol = aligned.iloc[:, 7]

        # Calculate SMA correlation
        sma5_corr = s1_sma5.corr(s2_sma5)
        sma10_corr = s1_sma10.corr(s2_sma10)

        if np.isnan(sma5_corr):
            sma5_corr = 0
        if np.isnan(sma10_corr):
            sma10_corr = 0

        # Normalize vol using mean volatility
        mean_vol = (s1_vol.mean() + s2_vol.mean()) / 2
        if mean_vol == 0:
            vol_penalty = 1.0  # Arbitrary strong penalty
        else:
            vol_penalty = abs(s1_vol.mean() - s2_vol.mean()) / mean_vol

        avg_sma_corr = (sma5_corr + sma10_corr) / 2  # Simple average of the two correlations

        # Cointegration p-value
        _, pvalue, _ = coint(s1_close, s2_close)

        # Combine into one score for BO to minimize
        alpha = 0.2  # weight for SMA correlation
        beta = 0.1   # weight for volatility mismatch

        score = pvalue + alpha * (1 - avg_sma_corr) + beta * vol_penalty

        return score

    # Greedy search loop
    while len(remaining_tickers) > 2:
        num_stocks = len(remaining_tickers)

        if num_stocks < 2:
            break

        # Define BO search space
        search_space = [(0, num_stocks - 1), (0, num_stocks - 1)]

        # Run Bayesian Optimization
        result = gp_minimize(cointegration_test, search_space, n_calls=n_calls, random_state=random_state)
        best_idx = sorted(result.x)
        best_pair = (remaining_tickers[best_idx[0]], remaining_tickers[best_idx[1]])
        best_pvalue = result.fun

        # Store only significant cointegrated pairs
        if best_pvalue < cointegration_threshold:
            print(f"✅ Cointegrated Pair Found: {best_pair} | p-value = {best_pvalue:.4f}")
            found_pairs.append((best_pair, best_pvalue))

        # Remove used tickers to avoid duplication
        remaining_tickers.remove(best_pair[0])
        remaining_tickers.remove(best_pair[1])

    # Final summary
    print(f"\n🎯 Total Cointegrated Pairs Found: {len(found_pairs)}")
    for pair, pval in found_pairs:
        print(f"{pair} | p = {pval:.4f}")

    return found_pairs

# co_pairs = find_cointegrated_pairs(combined_df, tickers)

# %%
yearly_cointegrations = {}

# Loop through 2019 start - 2020 start TO 2023 start - 2024 start
for year in range(2019, 2024):
    start_date = f"{year}-01-01"
    end_date = f"{year+1}-01-01"
    print(f"==== Processing data for {start_date} to {end_date} ====")
    
    # Use the extraction function
    sp500_data_year = fetch_sp500_data(start_date, end_date)
    
    # Prepare data
    close_price_year, stock_pairs_year, tickers_year = prepare_close_prices_and_pairs(sp500_data_year)
    combined_df_year = calculate_indicators(close_price_year)
    
    # Find cointegrated pairs for this year
    co_pairs_year = find_cointegrated_pairs(combined_df_year, tickers_year)
    yearly_cointegrations[year] = co_pairs_year

print("All yearly cointegration results:", yearly_cointegrations)
# Out:
# ==== Processing data for 2019-01-01 to 2020-01-01 ====
# [*********************100%***********************]  503 of 503 completed
#
# 16 Failed downloads:
# ['VLTO', 'EXE', 'OTIS', 'CEG', 'CARR', 'SOLV', 'SW', 'GEHC', 'KVUE', 'PLTR', 'GEV', 'ABNB', 'DASH']: YFPricesMissingError('possibly delisted; no price data found  (1d 2019-01-01 -> 2020-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1546318800, endDate = 1577854800")')
# ['BF.B', 'WDC']: YFPricesMissingError('possibly delisted; no price data found  (1d 2019-01-01 -> 2020-01-01)')
# ['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# Price       Adj Close                                                   \
# Ticker              A       AAPL       ABBV ABNB        ABT       ACGL
# Date
# 2019-01-02  62.944958  37.667202  67.518402  NaN  62.330669  24.904034
# 2019-01-03  60.626076  33.915257  65.293770  NaN  59.389023  24.514164
# 2019-01-04  62.724556  35.363071  67.397339  NaN  61.084068  25.094212
# 2019-01-07  64.056473  35.284363  68.381027  NaN  61.998833  25.037159
# 2019-01-08  64.995537  35.956993  68.698807  NaN  61.254475  25.132248
#
# Price                                                     ...  Volume  \
# Ticker             ACN        ADBE        ADI        ADM  ...     WTW
# Date                                                      ...
# 2019-01-02  129.003677  224.570007  76.502014  34.205593  ...  743800
# 2019-01-03  124.599236  215.699997  71.880898  34.055241  ...  689800
# 2019-01-04  129.444122  226.190002  73.626038  34.840427  ...  842100
# 2019-01-07  129.893692  229.259995  74.089066  35.015835  ...  879200
# 2019-01-08  133.178726  232.679993  75.896515  35.667370  ...  885300
#
# Price                                                                       \
# Ticker           WY     WYNN      XEL       XOM      XYL      YUM      ZBH
# Date
# 2019-01-02  7442000  4174400  4476100  16727200   990900  1743400  1186663
# 2019-01-03  9788300  2885100  5287600  13866100  1243100  2680300  1201083
# 2019-01-04  5843900  3007200  5535600  16043600   970900  2142700  1627812
# 2019-01-07  6562200  3143800  4208100  10844200  1341600  2561100   927309
# 2019-01-08  6232800  2255700  3128300  11439000   912800  2604700  3356770
#
# Price
# Ticker         ZBRA      ZTS
# Date
# 2019-01-02   347700  2665600
# 2019-01-03   514600  2390900
# 2019-01-04   723300  3383500
# 2019-01-07  1100000  2360800
# 2019-01-08   838500  2250300
#
# [5 rows x 3018 columns]
# ✅ Cointegrated Pair Found: ('ACN', 'MKC') | p-value = 0.0412
# ✅ Cointegrated Pair Found: ('AMT', 'VMC') | p-value = 0.0488
# ✅ Cointegrated Pair Found: ('ACGL', 'MLM') | p-value = 0.0307
# ✅ Cointegrated Pair Found: ('CMG', 'SNPS') | p-value = 0.0401
# ✅ Cointegrated Pair Found: ('AEP', 'JCI') | p-value = 0.0495
# ✅ Cointegrated Pair Found: ('EW', 'FI') | p-value = 0.0300
# ✅ Cointegrated Pair Found: ('AVB', 'XEL') | p-value = 0.0322
# ✅ Cointegrated Pair Found: ('FE', 'T') | p-value = 0.0321
# ✅ Cointegrated Pair Found: ('AMAT', 'LULU') | p-value = 0.0323
# ✅ Cointegrated Pair Found: ('COP', 'RL') | p-value = 0.0451
# ✅ Cointegrated Pair Found: ('MCD', 'YUM') | p-value = 0.0473
# ✅ Cointegrated Pair Found: ('PLD', 'SO') | p-value = 0.0293
# ✅ Cointegrated Pair Found: ('AVY', 'ORLY') | p-value = 0.0107
# ✅ Cointegrated Pair Found: ('ETN', 'GRMN') | p-value = 0.0238
# ✅ Cointegrated Pair Found: ('BX', 'HIG') | p-value = 0.0495
# ✅ Cointegrated Pair Found: ('AME', 'CHTR') | p-value = 0.0458
# ✅ Cointegrated Pair Found: ('HLT', 'TMO') | p-value = 0.0171
# ✅ Cointegrated Pair Found: ('LNT', 'PG') | p-value = 0.0211
# ✅ Cointegrated Pair Found: ('BDX', 'NWSA') | p-value = 0.0427
# ✅ Cointegrated Pair Found: ('BRO', 'MCO') | p-value = 0.0378
# ✅ Cointegrated Pair Found: ('TDG', 'TROW') | p-value = 0.0192
# ✅ Cointegrated Pair Found: ('CINF', 'LHX') | p-value = 0.0452
# ✅ Cointegrated Pair Found: ('IPG', 'MTB') | p-value = 0.0236
# ✅ Cointegrated Pair Found: ('CSGP', 'KMB') | p-value = 0.0469
# ✅ Cointegrated Pair Found: ('IT', 'NSC') | p-value = 0.0411
# ✅ Cointegrated Pair Found: ('ITW', 'RTX') | p-value = 0.0423
# ✅ Cointegrated Pair Found: ('DGX', 'MA') | p-value = 0.0249
#
# 🎯 Total Cointegrated Pairs Found: 27
# ('ACN', 'MKC') | p = 0.0412
# ('AMT', 'VMC') | p = 0.0488
# ('ACGL', 'MLM') | p = 0.0307
# ('CMG', 'SNPS') | p = 0.0401
# ('AEP', 'JCI') | p = 0.0495
# ('EW', 'FI') | p = 0.0300
# ('AVB', 'XEL') | p = 0.0322
# ('FE', 'T') | p = 0.0321
# ('AMAT', 'LULU') | p = 0.0323
# ('COP', 'RL') | p = 0.0451
# ('MCD', 'YUM') | p = 0.0473
# ('PLD', 'SO') | p = 0.0293
# ('AVY', 'ORLY') | p = 0.0107
# ('ETN', 'GRMN') | p = 0.0238
# ('BX', 'HIG') | p = 0.0495
# ('AME', 'CHTR') | p = 0.0458
# ('HLT', 'TMO') | p = 0.0171
# ('LNT', 'PG') | p = 0.0211
# ('BDX', 'NWSA') | p = 0.0427
# ('BRO', 'MCO') | p = 0.0378
# ('TDG', 'TROW') | p = 0.0192
# ('CINF', 'LHX') | p = 0.0452
# ('IPG', 'MTB') | p = 0.0236
# ('CSGP', 'KMB') | p = 0.0469
# ('IT', 'NSC') | p = 0.0411
# ('ITW', 'RTX') | p = 0.0423
# ('DGX', 'MA') | p = 0.0249
# ==== Processing data for 2020-01-01 to 2021-01-01 ====
# [*********************100%***********************]  503 of 503 completed
#
# 11 Failed downloads:
# ['VLTO', 'EXE', 'CEG', 'SOLV', 'SW', 'GEHC', 'KVUE', 'GEV']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2021-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1577854800, endDate = 1609477200")')
# ['BF.B', 'WDC']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2021-01-01)')
# ['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# Price       Adj Close                                                   \
# Ticker              A       AAPL       ABBV ABNB        ABT       ACGL
# Date
# 2020-01-02  83.061333  72.716087  71.589783  NaN  79.273956  41.268997
# 2020-01-03  81.727730  72.009125  70.910248  NaN  78.307510  41.221451
# 2020-01-06  81.969322  72.582916  71.469856  NaN  78.717804  41.383106
# 2020-01-07  82.220581  72.241554  71.062164  NaN  78.280167  41.040779
# 2020-01-08  83.032349  73.403648  71.565796  NaN  78.599274  40.631893
#
# Price                                                      ...  Volume  \
# Ticker             ACN        ADBE         ADI        ADM  ...     WTW
# Date                                                       ...
# 2020-01-02  195.263565  334.429993  109.436218  39.867687  ...  465800
# 2020-01-03  194.938370  331.809998  107.509750  39.789875  ...  411400
# 2020-01-06  193.665405  333.709991  106.246643  39.478622  ...  620200
# 2020-01-07  189.484161  333.390015  108.663811  39.003075  ...  443200
# 2020-01-08  189.855881  337.869995  109.645226  38.570770  ...  486400
#
# Price                                                                       \
# Ticker           WY     WYNN      XEL       XOM      XYL      YUM      ZBH
# Date
# 2020-01-02  4973500  3006500  2915400  12456400   869500  1369900  1083972
# 2020-01-03  3111000  1760500  2422500  17386900   795100  1145500   992405
# 2020-01-06  2178600  1357900  2217100  20081900   817300  1454100   972423
# 2020-01-07  2426200  1722100  1861100  17387700   662200  1388600   934519
# 2020-01-08  2299800  1176200  4828900  15137700  1083200  1521500   936064
#
# Price
# Ticker        ZBRA      ZTS
# Date
# 2020-01-02  387800  1576700
# 2020-01-03  305300  1274000
# 2020-01-06  322600  2334100
# 2020-01-07  236300  1224500
# 2020-01-08  689600  1766700
#
# [5 rows x 3018 columns]
# ✅ Cointegrated Pair Found: ('A', 'VRSK') | p-value = 0.0284
# ✅ Cointegrated Pair Found: ('CF', 'RJF') | p-value = 0.0459
# ✅ Cointegrated Pair Found: ('ALLE', 'JPM') | p-value = 0.0259
# ✅ Cointegrated Pair Found: ('AMCR', 'KKR') | p-value = 0.0273
# ✅ Cointegrated Pair Found: ('CAT', 'MTD') | p-value = 0.0405
# ✅ Cointegrated Pair Found: ('ADBE', 'ODFL') | p-value = 0.0496
# ✅ Cointegrated Pair Found: ('BKNG', 'NWSA') | p-value = 0.0236
# ✅ Cointegrated Pair Found: ('MAR', 'RF') | p-value = 0.0285
# ✅ Cointegrated Pair Found: ('AIG', 'KEY') | p-value = 0.0392
# ✅ Cointegrated Pair Found: ('DOC', 'USB') | p-value = 0.0382
# ✅ Cointegrated Pair Found: ('HST', 'WYNN') | p-value = 0.0366
# ✅ Cointegrated Pair Found: ('MCHP', 'ON') | p-value = 0.0463
# ✅ Cointegrated Pair Found: ('ERIE', 'IDXX') | p-value = 0.0076
# ✅ Cointegrated Pair Found: ('CSX', 'STLD') | p-value = 0.0399
# ✅ Cointegrated Pair Found: ('MCK', 'PTC') | p-value = 0.0464
# ✅ Cointegrated Pair Found: ('ABT', 'CMG') | p-value = 0.0357
# ✅ Cointegrated Pair Found: ('BEN', 'VICI') | p-value = 0.0440
# ✅ Cointegrated Pair Found: ('MDLZ', 'WM') | p-value = 0.0483
# ✅ Cointegrated Pair Found: ('NTRS', 'UHS') | p-value = 0.0422
# ✅ Cointegrated Pair Found: ('AOS', 'NOW') | p-value = 0.0341
# ✅ Cointegrated Pair Found: ('BAC', 'HIG') | p-value = 0.0254
# ✅ Cointegrated Pair Found: ('AVY', 'HON') | p-value = 0.0491
# ✅ Cointegrated Pair Found: ('MHK', 'ROST') | p-value = 0.0444
# ✅ Cointegrated Pair Found: ('ADM', 'BALL') | p-value = 0.0262
# ✅ Cointegrated Pair Found: ('LVS', 'WBD') | p-value = 0.0324
# ✅ Cointegrated Pair Found: ('CTSH', 'PPG') | p-value = 0.0472
# ✅ Cointegrated Pair Found: ('COP', 'CVX') | p-value = 0.0346
# ✅ Cointegrated Pair Found: ('BLK', 'GRMN') | p-value = 0.0392
# ✅ Cointegrated Pair Found: ('CTVA', 'SBUX') | p-value = 0.0411
# ✅ Cointegrated Pair Found: ('MOS', 'WY') | p-value = 0.0499
# ✅ Cointegrated Pair Found: ('AXON', 'PAYC') | p-value = 0.0226
# ✅ Cointegrated Pair Found: ('HUM', 'LULU') | p-value = 0.0462
# ✅ Cointegrated Pair Found: ('AWK', 'PG') | p-value = 0.0436
# ✅ Cointegrated Pair Found: ('DE', 'QCOM') | p-value = 0.0284
# ✅ Cointegrated Pair Found: ('ANSS', 'EMN') | p-value = 0.0387
# ✅ Cointegrated Pair Found: ('APD', 'ORLY') | p-value = 0.0313
# ✅ Cointegrated Pair Found: ('FIS', 'MMC') | p-value = 0.0352
# ✅ Cointegrated Pair Found: ('SYF', 'TXT') | p-value = 0.0329
# ✅ Cointegrated Pair Found: ('BG', 'PAYX') | p-value = 0.0307
# ✅ Cointegrated Pair Found: ('SPG', 'UAL') | p-value = 0.0196
# ✅ Cointegrated Pair Found: ('ANET', 'KEYS') | p-value = 0.0327
# ✅ Cointegrated Pair Found: ('ATO', 'EVRG') | p-value = 0.0493
# ✅ Cointegrated Pair Found: ('IR', 'PNR') | p-value = 0.0428
# ✅ Cointegrated Pair Found: ('HES', 'TPL') | p-value = 0.0346
# ✅ Cointegrated Pair Found: ('EOG', 'FANG') | p-value = 0.0329
# ✅ Cointegrated Pair Found: ('DVN', 'MPC') | p-value = 0.0426
# ✅ Cointegrated Pair Found: ('OKE', 'REG') | p-value = 0.0349
# ✅ Cointegrated Pair Found: ('CTAS', 'GLW') | p-value = 0.0392
#
# 🎯 Total Cointegrated Pairs Found: 48
# ('A', 'VRSK') | p = 0.0284
# ('CF', 'RJF') | p = 0.0459
# ('ALLE', 'JPM') | p = 0.0259
# ('AMCR', 'KKR') | p = 0.0273
# ('CAT', 'MTD') | p = 0.0405
# ('ADBE', 'ODFL') | p = 0.0496
# ('BKNG', 'NWSA') | p = 0.0236
# ('MAR', 'RF') | p = 0.0285
# ('AIG', 'KEY') | p = 0.0392
# ('DOC', 'USB') | p = 0.0382
# ('HST', 'WYNN') | p = 0.0366
# ('MCHP', 'ON') | p = 0.0463
# ('ERIE', 'IDXX') | p = 0.0076
# ('CSX', 'STLD') | p = 0.0399
# ('MCK', 'PTC') | p = 0.0464
# ('ABT', 'CMG') | p = 0.0357
# ('BEN', 'VICI') | p = 0.0440
# ('MDLZ', 'WM') | p = 0.0483
# ('NTRS', 'UHS') | p = 0.0422
# ('AOS', 'NOW') | p = 0.0341
# ('BAC', 'HIG') | p = 0.0254
# ('AVY', 'HON') | p = 0.0491
# ('MHK', 'ROST') | p = 0.0444
# ('ADM', 'BALL') | p = 0.0262
# ('LVS', 'WBD') | p = 0.0324
# ('CTSH', 'PPG') | p = 0.0472
# ('COP', 'CVX') | p = 0.0346
# ('BLK', 'GRMN') | p = 0.0392
# ('CTVA', 'SBUX') | p = 0.0411
# ('MOS', 'WY') | p = 0.0499
# ('AXON', 'PAYC') | p = 0.0226
# ('HUM', 'LULU') | p = 0.0462
# ('AWK', 'PG') | p = 0.0436
# ('DE', 'QCOM') | p = 0.0284
# ('ANSS', 'EMN') | p = 0.0387
# ('APD', 'ORLY') | p = 0.0313
# ('FIS', 'MMC') | p = 0.0352
# ('SYF', 'TXT') | p = 0.0329
# ('BG', 'PAYX') | p = 0.0307
# ('SPG', 'UAL') | p = 0.0196
# ('ANET', 'KEYS') | p = 0.0327
# ('ATO', 'EVRG') | p = 0.0493
# ('IR', 'PNR') | p = 0.0428
# ('HES', 'TPL') | p = 0.0346
# ('EOG', 'FANG') | p = 0.0329
# ('DVN', 'MPC') | p = 0.0426
# ('OKE', 'REG') | p = 0.0349
# ('CTAS', 'GLW') | p = 0.0392
# ==== Processing data for 2021-01-01 to 2022-01-01 ====
# [*********************100%***********************]  503 of 503 completed
#
# 10 Failed downloads:
# ['VLTO', 'CEG', 'SOLV', 'SW', 'GEHC', 'KVUE', 'GEV']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-01-01 -> 2022-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1609477200, endDate = 1641013200")')
# ['BF.B', 'LRCX']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-01-01 -> 2022-01-01)')
# ['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# Price        Adj Close                                                 \
# Ticker               A        AAPL       ABBV        ABNB         ABT
# Date
# 2021-01-04  115.582764  126.405251  88.933960  139.149994  101.045967
# 2021-01-05  116.527771  127.968071  89.853584  148.300003  102.296181
# 2021-01-06  119.723228  123.660484  89.077385  142.770004  102.083191
# 2021-01-07  122.908981  127.880165  90.030762  151.270004  103.074112
# 2021-01-08  123.785789  128.983948  90.503220  149.770004  103.361191
#
# Price                                                                 ...  \
# Ticker           ACGL         ACN        ADBE         ADI        ADM  ...
# Date                                                                  ...
# 2021-01-04  33.186359  242.118515  485.339996  135.426224  44.578201  ...
# 2021-01-05  33.319485  243.496872  485.690002  137.846832  45.445274  ...
# 2021-01-06  34.783871  246.159180  466.309998  138.468231  47.286694  ...
# 2021-01-07  34.460564  248.481583  477.739990  144.320450  46.866562  ...
# 2021-01-08  34.650742  249.387909  485.100006  145.368469  46.991707  ...
#
# Price        Volume                                                         \
# Ticker          WTW       WY     WYNN      XEL       XOM      XYL      YUM
# Date
# 2021-01-04  1654000  4859100  3596800  3197100  27764700   814700  2058200
# 2021-01-05  1435000  3909000  1814600  1976800  44035100  1005200  1475300
# 2021-01-06  1792300  5602100  2433700  2667000  36484800  1015300  1352700
# 2021-01-07  1324300  3984700  3846700  2630400  29528100  1539300  2222900
# 2021-01-08   925300  4376000  2812400  2221500  28628200  1632200  1252200
#
# Price
# Ticker          ZBH    ZBRA      ZTS
# Date
# 2021-01-04  1265870  432600  1805900
# 2021-01-05   998894  374700  1358600
# 2021-01-06  1424799  419500  2139800
# 2021-01-07  1237648  379900  1710700
# 2021-01-08  1259072  348500  1475900
#
# [5 rows x 3018 columns]
# ✅ Cointegrated Pair Found: ('EVRG', 'YUM') | p-value = 0.0162
# ✅ Cointegrated Pair Found: ('EQR', 'ZTS') | p-value = 0.0337
# ✅ Cointegrated Pair Found: ('AZO', 'FAST') | p-value = 0.0400
# ✅ Cointegrated Pair Found: ('DHR', 'ISRG') | p-value = 0.0265
# ✅ Cointegrated Pair Found: ('NDSN', 'WAB') | p-value = 0.0400
# ✅ Cointegrated Pair Found: ('AMT', 'OTIS') | p-value = 0.0214
# ✅ Cointegrated Pair Found: ('ARE', 'UDR') | p-value = 0.0250
# ✅ Cointegrated Pair Found: ('CBRE', 'MOH') | p-value = 0.0258
# ✅ Cointegrated Pair Found: ('ORLY', 'PSA') | p-value = 0.0245
# ✅ Cointegrated Pair Found: ('MA', 'NWSA') | p-value = 0.0493
# ✅ Cointegrated Pair Found: ('CNP', 'O') | p-value = 0.0385
# ✅ Cointegrated Pair Found: ('WDC', 'WYNN') | p-value = 0.0493
# ✅ Cointegrated Pair Found: ('GOOGL', 'IT') | p-value = 0.0212
# ✅ Cointegrated Pair Found: ('HCA', 'IPG') | p-value = 0.0327
# ✅ Cointegrated Pair Found: ('CBOE', 'FTNT') | p-value = 0.0327
# ✅ Cointegrated Pair Found: ('LLY', 'NKE') | p-value = 0.0484
#
# 🎯 Total Cointegrated Pairs Found: 16
# ('EVRG', 'YUM') | p = 0.0162
# ('EQR', 'ZTS') | p = 0.0337
# ('AZO', 'FAST') | p = 0.0400
# ('DHR', 'ISRG') | p = 0.0265
# ('NDSN', 'WAB') | p = 0.0400
# ('AMT', 'OTIS') | p = 0.0214
# ('ARE', 'UDR') | p = 0.0250
# ('CBRE', 'MOH') | p = 0.0258
# ('ORLY', 'PSA') | p = 0.0245
# ('MA', 'NWSA') | p = 0.0493
# ('CNP', 'O') | p = 0.0385
# ('WDC', 'WYNN') | p = 0.0493
# ('GOOGL', 'IT') | p = 0.0212
# ('HCA', 'IPG') | p = 0.0327
# ('CBOE', 'FTNT') | p = 0.0327
# ('LLY', 'NKE') | p = 0.0484
# ==== Processing data for 2022-01-01 to 2023-01-01 ====
# [*********************100%***********************]  503 of 503 completed
#
# 8 Failed downloads:
# ['VLTO', 'SOLV', 'SW', 'KVUE', 'GEV']: YFPricesMissingError('possibly delisted; no price data found  (1d 2022-01-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1672549200")')
# ['BF.B', 'LRCX']: YFPricesMissingError('possibly delisted; no price data found  (1d 2022-01-01 -> 2023-01-01)')
# ['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# Price        Adj Close                                                  \
# Ticker               A        AAPL        ABBV        ABNB         ABT
# Date
# 2022-01-03  153.272278  178.879898  119.733437  172.679993  130.754242
# 2022-01-04  148.090729  176.609650  119.503555  170.800003  127.679146
# 2022-01-05  145.553818  171.911835  120.131332  162.250000  127.105469
# 2022-01-06  146.063141  169.042084  119.565460  159.750000  127.086632
# 2022-01-07  142.174515  169.209137  119.256020  166.050003  127.481651
#
# Price                                                                 ...  \
# Ticker           ACGL         ACN        ADBE         ADI        ADM  ...
# Date                                                                  ...
# 2022-01-03  42.362530  389.190216  564.369995  167.036636  62.154781  ...
# 2022-01-04  42.914051  386.409058  554.000000  165.527969  63.308331  ...
# 2022-01-05  42.410072  379.604126  514.429993  162.972656  62.813969  ...
# 2022-01-06  42.657307  361.272827  514.119995  163.491272  63.372425  ...
# 2022-01-07  42.856995  354.343689  510.700012  159.201050  63.912590  ...
#
# Price        Volume                                                         \
# Ticker          WTW       WY     WYNN      XEL       XOM      XYL      YUM
# Date
# 2022-01-03   848600  3831100  2437800  3501100  24282400   759100  1251400
# 2022-01-04   952100  3089700  2292300  4197000  38584000   925400   935900
# 2022-01-05  1070500  3737600  3439900  4166000  34033300  1090200   977900
# 2022-01-06  1128100  3315200  2583200  2296000  30668500   703400   862400
# 2022-01-07  1233500  3309900  1720400  2673100  23985400   765000   833700
#
# Price
# Ticker          ZBH    ZBRA      ZTS
# Date
# 2022-01-03  1184809  272600  2772700
# 2022-01-04  1400800  346000  4664000
# 2022-01-05  1895715  403700  4749400
# 2022-01-06  1088813  338300  3103400
# 2022-01-07  1690230  432800  2206500
#
# [5 rows x 3018 columns]
# ✅ Cointegrated Pair Found: ('AMAT', 'BBY') | p-value = 0.0281
# ✅ Cointegrated Pair Found: ('AMD', 'META') | p-value = 0.0384
# ✅ Cointegrated Pair Found: ('CDW', 'ORCL') | p-value = 0.0466
# ✅ Cointegrated Pair Found: ('AVB', 'CME') | p-value = 0.0232
# ✅ Cointegrated Pair Found: ('AES', 'MSI') | p-value = 0.0401
# ✅ Cointegrated Pair Found: ('BALL', 'GRMN') | p-value = 0.0302
# ✅ Cointegrated Pair Found: ('MLM', 'VRSN') | p-value = 0.0462
# ✅ Cointegrated Pair Found: ('ADP', 'GWW') | p-value = 0.0423
# ✅ Cointegrated Pair Found: ('LOW', 'RF') | p-value = 0.0329
# ✅ Cointegrated Pair Found: ('ECL', 'PLD') | p-value = 0.0384
# ✅ Cointegrated Pair Found: ('IPG', 'OMC') | p-value = 0.0354
# ✅ Cointegrated Pair Found: ('PNR', 'SWKS') | p-value = 0.0388
# ✅ Cointegrated Pair Found: ('BAC', 'NWSA') | p-value = 0.0458
# ✅ Cointegrated Pair Found: ('JNPR', 'UHS') | p-value = 0.0378
# ✅ Cointegrated Pair Found: ('LNT', 'SBAC') | p-value = 0.0499
# ✅ Cointegrated Pair Found: ('AEE', 'EIX') | p-value = 0.0353
# ✅ Cointegrated Pair Found: ('EFX', 'SPGI') | p-value = 0.0407
# ✅ Cointegrated Pair Found: ('HUM', 'TKO') | p-value = 0.0207
# ✅ Cointegrated Pair Found: ('CINF', 'LYB') | p-value = 0.0454
#
# 🎯 Total Cointegrated Pairs Found: 19
# ('AMAT', 'BBY') | p = 0.0281
# ('AMD', 'META') | p = 0.0384
# ('CDW', 'ORCL') | p = 0.0466
# ('AVB', 'CME') | p = 0.0232
# ('AES', 'MSI') | p = 0.0401
# ('BALL', 'GRMN') | p = 0.0302
# ('MLM', 'VRSN') | p = 0.0462
# ('ADP', 'GWW') | p = 0.0423
# ('LOW', 'RF') | p = 0.0329
# ('ECL', 'PLD') | p = 0.0384
# ('IPG', 'OMC') | p = 0.0354
# ('PNR', 'SWKS') | p = 0.0388
# ('BAC', 'NWSA') | p = 0.0458
# ('JNPR', 'UHS') | p = 0.0378
# ('LNT', 'SBAC') | p = 0.0499
# ('AEE', 'EIX') | p = 0.0353
# ('EFX', 'SPGI') | p = 0.0407
# ('HUM', 'TKO') | p = 0.0207
# ('CINF', 'LYB') | p = 0.0454
# ==== Processing data for 2023-01-01 to 2024-01-01 ====
# [*********************100%***********************]  503 of 503 completed
#
# 6 Failed downloads:
# ['BF.B', 'LRCX']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-01-01 -> 2024-01-01)')
# ['SOLV', 'SW', 'GEV']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-01-01 -> 2024-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1672549200, endDate = 1704085200")')
# ['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# Price        Adj Close                                                 \
# Ticker               A        AAPL        ABBV       ABNB         ABT
# Date
# 2023-01-03  147.931244  123.632530  149.164093  84.900002  104.779045
# 2023-01-04  149.538361  124.907707  150.367493  88.720001  106.337631
# 2023-01-05  149.972153  123.583092  150.183777  87.709999  105.945610
# 2023-01-06  145.594528  128.130249  152.994736  88.519997  107.408569
# 2023-01-09  145.397354  128.654160  148.502716  89.239998  107.236450
#
# Price                                                                 ...  \
# Ticker           ACGL         ACN        ADBE         ADI        ADM  ...
# Date                                                                  ...
# 2023-01-03  59.393120  261.824371  336.920013  156.076004  83.634407  ...
# 2023-01-04  59.687901  260.933044  341.410004  159.400269  80.593147  ...
# 2023-01-05  59.849552  254.771591  328.440002  153.424286  78.578087  ...
# 2023-01-06  60.762417  260.807129  332.750000  159.025543  80.182671  ...
# 2023-01-09  59.592808  265.205444  341.980011  160.543564  79.641594  ...
#
# Price       Volume                                                         \
# Ticker         WTW       WY     WYNN      XEL       XOM      XYL      YUM
# Date
# 2023-01-03  591300  2939100  3318600  2684500  15146200   812400  2307100
# 2023-01-04  547200  3287700  5743600  2265900  18058400   905900  1139400
# 2023-01-05  328600  2976200  2983000  2104500  15946600  1295700  1078200
# 2023-01-06  610800  2890600  2901900  2976200  16348100   636200  1559400
# 2023-01-09  548300  2511100  2751000  2707800  17964600  1224700  1211200
#
# Price
# Ticker          ZBH    ZBRA      ZTS
# Date
# 2023-01-03   921100  295400  1840600
# 2023-01-04  1389400  311600  1796100
# 2023-01-05  2238300  368200  1560900
# 2023-01-06  2348900  552700  1761200
# 2023-01-09  1423600  535400  1700500
#
# [5 rows x 3018 columns]
# ✅ Cointegrated Pair Found: ('EXPD', 'MLM') | p-value = 0.0483
# ✅ Cointegrated Pair Found: ('CMS', 'RTX') | p-value = 0.0429
# ✅ Cointegrated Pair Found: ('FE', 'WEC') | p-value = 0.0287
# ✅ Cointegrated Pair Found: ('AWK', 'HOLX') | p-value = 0.0294
# ✅ Cointegrated Pair Found: ('BEN', 'FRT') | p-value = 0.0476
# ✅ Cointegrated Pair Found: ('HSIC', 'UPS') | p-value = 0.0216
# ✅ Cointegrated Pair Found: ('ES', 'TSCO') | p-value = 0.0416
# ✅ Cointegrated Pair Found: ('GE', 'TTWO') | p-value = 0.0251
# ✅ Cointegrated Pair Found: ('ENPH', 'WBD') | p-value = 0.0373
# ✅ Cointegrated Pair Found: ('SCHW', 'USB') | p-value = 0.0289
# ✅ Cointegrated Pair Found: ('AVGO', 'KLAC') | p-value = 0.0413
# ✅ Cointegrated Pair Found: ('SRE', 'VICI') | p-value = 0.0492
# ✅ Cointegrated Pair Found: ('DIS', 'T') | p-value = 0.0359
# ✅ Cointegrated Pair Found: ('AVB', 'LOW') | p-value = 0.0475
# ✅ Cointegrated Pair Found: ('BAX', 'TECH') | p-value = 0.0421
# ✅ Cointegrated Pair Found: ('IR', 'TDG') | p-value = 0.0398
# ✅ Cointegrated Pair Found: ('KIM', 'NSC') | p-value = 0.0450
#
# 🎯 Total Cointegrated Pairs Found: 17
# ('EXPD', 'MLM') | p = 0.0483
# ('CMS', 'RTX') | p = 0.0429
# ('FE', 'WEC') | p = 0.0287
# ('AWK', 'HOLX') | p = 0.0294
# ('BEN', 'FRT') | p = 0.0476
# ('HSIC', 'UPS') | p = 0.0216
# ('ES', 'TSCO') | p = 0.0416
# ('GE', 'TTWO') | p = 0.0251
# ('ENPH', 'WBD') | p = 0.0373
# ('SCHW', 'USB') | p = 0.0289
# ('AVGO', 'KLAC') | p = 0.0413
# ('SRE', 'VICI') | p = 0.0492
# ('DIS', 'T') | p = 0.0359
# ('AVB', 'LOW') | p = 0.0475
# ('BAX', 'TECH') | p = 0.0421
# ('IR', 'TDG') | p = 0.0398
# ('KIM', 'NSC') | p = 0.0450
# All yearly cointegration results: {2019: [(('ACN', 'MKC'), np.float64(0.041165500407344145)), (('AMT', 'VMC'), np.float64(0.04882865700279417)), (('ACGL', 'MLM'), np.float64(0.03065663597633094)), (('CMG', 'SNPS'), np.float64(0.04005440437290848)), (('AEP', 'JCI'), np.float64(0.0495076024205747)), (('EW', 'FI'), np.float64(0.030009092330943333)), (('AVB', 'XEL'), np.float64(0.03218948592190064)), (('FE', 'T'), np.float64(0.03211699475726322)), (('AMAT', 'LULU'), np.float64(0.03227789535340684)), (('COP', 'RL'), np.float64(0.04510796254957873)), (('MCD', 'YUM'), np.float64(0.047320972547966585)), (('PLD', 'SO'), np.float64(0.02934345805299236)), (('AVY', 'ORLY'), np.float64(0.01074901351249449)), (('ETN', 'GRMN'), np.float64(0.02383451935590148)), (('BX', 'HIG'), np.float64(0.049490079621288874)), (('AME', 'CHTR'), np.float64(0.04581837154035538)), (('HLT', 'TMO'), np.float64(0.01707841024398844)), (('LNT', 'PG'), np.float64(0.02111741837400567)), (('BDX', 'NWSA'), np.float64(0.04265969935229696)), (('BRO', 'MCO'), np.float64(0.03777789107598205)), (('TDG', 'TROW'), np.float64(0.019162081592583518)), (('CINF', 'LHX'), np.float64(0.04524515676788257)), (('IPG', 'MTB'), np.float64(0.023565623136315852)), (('CSGP', 'KMB'), np.float64(0.04689968521920833)), (('IT', 'NSC'), np.float64(0.041144732325320406)), (('ITW', 'RTX'), np.float64(0.04229470038565637)), (('DGX', 'MA'), np.float64(0.02487733145358712))], 2020: [(('A', 'VRSK'), np.float64(0.028439631162637702)), (('CF', 'RJF'), np.float64(0.04593063306106339)), (('ALLE', 'JPM'), np.float64(0.02589842973564909)), (('AMCR', 'KKR'), np.float64(0.02729336572919868)), (('CAT', 'MTD'), np.float64(0.04050186006823111)), (('ADBE', 'ODFL'), np.float64(0.0496191712400827)), (('BKNG', 'NWSA'), np.float64(0.02362992440942281)), (('MAR', 'RF'), np.float64(0.028508265129610192)), (('AIG', 'KEY'), np.float64(0.03921685070354945)), (('DOC', 'USB'), np.float64(0.03824447033421948)), (('HST', 'WYNN'), np.float64(0.03660571912025125)), (('MCHP', 'ON'), np.float64(0.04625968148236339)), (('ERIE', 'IDXX'), np.float64(0.007568242075125535)), (('CSX', 'STLD'), np.float64(0.03990891735357662)), (('MCK', 'PTC'), np.float64(0.04641180907212933)), (('ABT', 'CMG'), np.float64(0.03566336728202091)), (('BEN', 'VICI'), np.float64(0.04400432584319209)), (('MDLZ', 'WM'), np.float64(0.04830831756233173)), (('NTRS', 'UHS'), np.float64(0.04216593282182664)), (('AOS', 'NOW'), np.float64(0.034092228162524565)), (('BAC', 'HIG'), np.float64(0.025424115623602722)), (('AVY', 'HON'), np.float64(0.049100962761985695)), (('MHK', 'ROST'), np.float64(0.04441448227163464)), (('ADM', 'BALL'), np.float64(0.02615937216831084)), (('LVS', 'WBD'), np.float64(0.03240938618756825)), (('CTSH', 'PPG'), np.float64(0.04721684477971491)), (('COP', 'CVX'), np.float64(0.03460689427391647)), (('BLK', 'GRMN'), np.float64(0.03920110318057466)), (('CTVA', 'SBUX'), np.float64(0.04113950680521508)), (('MOS', 'WY'), np.float64(0.04991391195997745)), (('AXON', 'PAYC'), np.float64(0.02257470170110168)), (('HUM', 'LULU'), np.float64(0.046217566672367996)), (('AWK', 'PG'), np.float64(0.04358222362944067)), (('DE', 'QCOM'), np.float64(0.028361089760390163)), (('ANSS', 'EMN'), np.float64(0.03867132621043707)), (('APD', 'ORLY'), np.float64(0.03134697536777606)), (('FIS', 'MMC'), np.float64(0.03517464101044305)), (('SYF', 'TXT'), np.float64(0.03287629882665813)), (('BG', 'PAYX'), np.float64(0.030655720611273952)), (('SPG', 'UAL'), np.float64(0.019555113344783652)), (('ANET', 'KEYS'), np.float64(0.032746142158734705)), (('ATO', 'EVRG'), np.float64(0.04932722319244612)), (('IR', 'PNR'), np.float64(0.042831789135241105)), (('HES', 'TPL'), np.float64(0.034619820870520866)), (('EOG', 'FANG'), np.float64(0.03287500235425229)), (('DVN', 'MPC'), np.float64(0.04256956800343392)), (('OKE', 'REG'), np.float64(0.03492910259790612)), (('CTAS', 'GLW'), np.float64(0.03918617493692147))], 2021: [(('EVRG', 'YUM'), np.float64(0.01621883874833342)), (('EQR', 'ZTS'), np.float ...

# %%
import json

# Export yearly_cointegrations as a JSON file
with open("yearly_cointegrations.json", "w") as json_file:
    json.dump(yearly_cointegrations, json_file, indent=4)

print("All yearly cointegration results have been saved to 'yearly_cointegrations.json'.")
# Out:
# All yearly cointegration results have been saved to 'yearly_cointegrations.json'.
